# %% [markdown]
# ### Pythonic way of extracting numbers from John Hopkins Covid19 Dashboard using ArcGIS API for Python

# %% [markdown]
# *As we all know ArcGIS Python API has rich pythonic library with all built-in functions.
# With the introduction of Spatial DataFrame into ArcGIS API, it enables us to immediately convert feature layers into dataframe which can be analyzed further. This is an attempt to automatically extract Country wise numbers (Active, Deaths, Confirmed) and US-County-Wise numbers (Confirmed,Deaths)*

# %% [markdown]
# ### Reference Links
# * [ArcGIS-Python-API](https://developers.arcgis.com/python/guide/)
# * [Pandas-Styling](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)
# * [Matplotlib-colormaps](https://matplotlib.org/examples/color/colormaps_reference.html)

# %%
from arcgis.gis import GIS
import pandas as pd
import numpy as np
# %matplotlib inline

#This is for displaying all outputs interactively in the notebook, not just the last-one which is default in Jupyter.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

'''For reference, the options for that are 'all', 'none', 'last' and 'last_expr'. 
The difference between 'last' and 'last_expr': if your cell ends with, say, a loop containing an expression, 
'last' will show you the results from that expression in each iteration of the loop. 
'last_expr' (the default) won't show that: it will only display the result of a bare expression at the end of the cell.'''
#https://stackoverflow.com/questions/36786722/how-to-display-full-output-in-jupyter-not-only-last-result


gis = GIS()

#Get the item ids of Layers from ArcGIS Online
itemUSCounties = gis.content.get('628578697fb24d8ea4c32fa0c5ae1843')
itemCountries = gis.content.get('c0b356e20b30490c8b8b4c7bb9554e7c')

#Get the feature layers from item.
deathsByUSCounty = itemUSCounties.layers[0]
deathsByCountry = itemCountries.layers[2]

#Create a country wise deaths spatial dataframe and check no of rows & columns
sdf = pd.DataFrame.spatial.from_layer(deathsByCountry)
print(f"Countrywise Deaths Feature Layer has {sdf.shape[0]} rows and {sdf.shape[1]} columns")

#Create a US County wise deaths spatial dataframe and check no.of rows & columns
sdfc = pd.DataFrame.spatial.from_layer(deathsByUSCounty)
print(f"US Counties Feature Layer has {sdfc.shape[0]} rows and {sdfc.shape[1]} columns")

#Adjust as per your requirements to display max rows/columns
pd.set_option('display.max_rows',100000)
pd.set_option('display.max_columns',10)

#Get Country wise Deaths,confirmed cases grouped by country sorted by deaths
sdfd = sdf[['Country_Region','Deaths','Confirmed','Recovered','Active']]
deathcount = sdfd.sort_values(by='Deaths',ascending=False)

deathcount.reset_index(drop=True,inplace=True)

#Apply gradient style and hide index
CountryWiseDeaths = deathcount.style.format({"Country_Region": lambda x:x.upper()})\
.background_gradient(cmap="Blues").hide_index()

#Apply bar style and hide index
CountryWiseDeaths_bar = deathcount.style.format({"Country_Region": lambda x:x.upper()})\
.bar(subset=["Deaths",], color='lightgreen')\
.bar(subset=["Confirmed"], color='#ee1f5f')\
.bar(subset=["Recovered"], color='#FFA07A')\
.bar(subset=["Active"],color="#ffa600").hide_index()

def plot_pandas_style(styler):
    """Currently pandas stylers have an unforatinate indent in the html they render
    See: https://github.com/pandas-dev/pandas/issues/15651

    Example
    -------
    plot_pandas_style(df.style.set_caption('this is my caption'))
    """
    from IPython.core.display import HTML
    html = '\n'.join([line.lstrip() for line in styler.render().split('\n')])
    return HTML(html)

#Display both
CountryWiseDeaths_bar
CountryWiseDeaths

#export to excel, csv as per your needs.
CountryWiseDeaths.to_excel('Covid-CountryWiseDeaths-data.xlsx')
# Out:
# "For reference, the options for that are 'all', 'none', 'last' and 'last_expr'. \nThe difference between 'last' and 'last_expr': if your cell ends with, say, a loop containing an expression, \n'last' will show you the results from that expression in each iteration of the loop. \n'last_expr' (the default) won't show that: it will only display the result of a bare expression at the end of the cell."
# Countrywise Deaths Feature Layer has 172 rows and 10 columns
# US Counties Feature Layer has 3168 rows and 16 columns
# <style  type="text/css" >
#     #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 91.1%, transparent 91.1%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 12.7%, transparent 12.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 100.0%, transparent 100.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 45.8%, transparent 45.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 58.3%, transparent 58.3%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 7.3%, transparent 7.3%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 67.5%, transparent 67.5%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 43.8%, transparent 43.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 100.0%, transparent 100.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 8.0%, transparent 8.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 27.7%, transparent 27.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 33.1%, transparent 33.1%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 13.0%, transparent 13.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 26.6%, transparent 26.6%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 14.7%, transparent 14.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 27.7%, transparent 27.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 4.5%, transparent 4.5%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 31.8%, transparent 31.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 11.0%, transparent 11.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 73.6%, transparent 73.6%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.5%, transparent 0.5%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow5_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 5.8%, transparent 5.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 10.2%, transparent 10.2%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.2%, transparent 0.2%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 13.5%, transparent 13.5%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 4.8%, transparent 4.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 7.9%, transparent 7.9%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.0%, transparent 0.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 10.6%, transparent 10.6%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 2.5%, transparent 2.5%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 43.8%, transparent 43.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 4.8%, transparent 4.8%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 55.7%, transparent 55.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 2.4%, transparent 2.4%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 6.0%, transparent 6.0%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.7%, transparent 0.7%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 7.3%, transparent 7.3%);
#         }    #T_f2a26464_6ec3_11ea_a3f3_a44cc866463arow10_col1 {
#             width:  10em;
# <style  type="text/css" >
#     #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow0_col2 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow0_col3 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow1_col1 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow1_col2 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow1_col3 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow1_col4 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow2_col1 {
#             background-color:  #84bcdb;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow2_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow2_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow3_col1 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow3_col2 {
#             background-color:  #add0e6;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow3_col3 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow3_col4 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow4_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow4_col2 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow4_col3 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow4_col4 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow5_col1 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow5_col2 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow5_col3 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow5_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow6_col1 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow6_col2 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow6_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow6_col4 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow7_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow7_col2 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow7_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow7_col4 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow8_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow8_col2 {
#             background-color:  #84bcdb;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow8_col3 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow8_col4 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow9_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow9_col2 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow9_col3 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow9_col4 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow10_col1 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow10_col2 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow10_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow10_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow11_col1 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow11_col2 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow11_col3 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow11_col4 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow12_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow12_col2 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow12_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow12_col4 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow13_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow13_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow13_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow13_col4 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow14_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow14_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow14_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f2c6c4e6_6ec3_11ea_82ae_a44cc866463arow14_col4 {
#             background-color:  #f1f7fd;

# %%
#Renaming 'Admin2' column in US Counties dataset to 'County' in the dataset
sdfc.rename(columns={"Admin2":"County"},inplace=True)

#Extract the required columns and sort them by deaths
sdfcounty = sdfc[['Province_State','County','Confirmed','Deaths']].copy()
sdfcounty.sort_values(by=['Deaths'],ascending=[False],inplace=True)

#Creating a pivot table and summing aggregation
df_pivot = pd.pivot_table(sdfcounty,values=['Confirmed','Deaths'],index=['Province_State','County'],aggfunc=np.sum)
df_pivot.sort_values(by='Deaths',ascending=False,inplace=True)

#Eliminating counties that have both confirmed and death cases as 0
#We want counties where there are confirmed cases but not deaths hence doing 'or' condition
filt = ~(df_pivot.Deaths == 0) | ~(df_pivot.Confirmed == 0)
df_pivot_filt = df_pivot[filt]


#Get the aggregated state,county dataframe without filtering
#----Use this if for exporting if you dont want filtering---------
b = pd.concat([
    d.append(d.sum().rename((k, 'TOTAL')))
    for k, d in df_pivot.groupby(level=0)
]).append(df_pivot.sum().rename(('USA-TOTAL', '')))

#b.style.apply(lambda x: ['background-color:red' if (x.Deaths>0) else '' for i in x], axis=1)

#Get the aggregated state, county dataframe with filtering along with subtotals per state & USA-Total.
a = pd.concat([
     d.append(d.sum().rename((k, 'TOTAL')))
     for k, d in df_pivot_filt.groupby(level=0)
 ]).append(df_pivot_filt.sum().rename(('USA-TOTAL', '')))

def plot_pandas_style(styler):
    """Currently pandas stylers have an unforatinate indent in the html they render
    See: https://github.com/pandas-dev/pandas/issues/15651

    Example
    -------
    plot_pandas_style(df.style.set_caption('this is my caption'))
    """
    from IPython.core.display import HTML
    html = '\n'.join([line.lstrip() for line in styler.render().split('\n')])
    return HTML(html)


#Applying styles - Light Red for sub-totals, Light blue for deaths>0, wheat for grand-total
final_df = a.style.apply(lambda x:['background-color:#FA8072' if x.name[1]=='TOTAL' else'' for i in x],axis=1)\
.apply(lambda x:['background-color:#87CEFA' if x.Deaths>0 and x.name[1]!='TOTAL' else'' for i in x],axis=1)\
.apply(lambda x:['background-color:#F5DEB3' if x.name[0]=='USA-TOTAL' else'' for i in x],axis=1)

#Similar to what we did earlier, you can also apply bar-styles if needed

#Printing just for verification
final_df


#export to excel, csv as per your needs.
final_df.to_excel('Covid-US-Countywise-data.xlsx')
# Out:
# <style  type="text/css" >
#     #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow28_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow28_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow34_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow34_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow35_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow35_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow36_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow36_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow37_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow37_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow38_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow38_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow47_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow47_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow48_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow48_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow49_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow49_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow87_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow87_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow88_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow88_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow89_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow89_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow90_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow90_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow91_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow91_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow92_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow92_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow93_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow93_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow94_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow94_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow95_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow95_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow96_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow96_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow97_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow97_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow98_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow98_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow99_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow99_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow100_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow100_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow101_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow101_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow102_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow102_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow103_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow103_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow104_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow104_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow105_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow105_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow130_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow130_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_fec7368c_6ec3_11ea_ad68_a44cc866463arow131_col0 {
#             : ;
