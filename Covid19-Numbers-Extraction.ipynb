# %% [markdown]
# ### Pythonic way of extracting numbers from John Hopkins Covid19 Dashboard using ArcGIS API for Python

# %% [markdown]
# *As we all know ArcGIS Python API has rich pythonic library with all built-in functions.
# With the introduction of Spatial DataFrame into ArcGIS API, it enables us to immediately convert feature layers into dataframe which can be analyzed further. This is an attempt to automatically extract Country wise numbers (Active, Deaths, Confirmed) and US-County-Wise numbers (Confirmed,Deaths)*

# %% [markdown]
# ### Reference Links
# * [ArcGIS-Python-API](https://developers.arcgis.com/python/guide/)
# * [Pandas-Styling](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)
# * [Matplotlib-colormaps](https://matplotlib.org/examples/color/colormaps_reference.html)

# %%
from arcgis.gis import GIS
import pandas as pd
import numpy as np
# %matplotlib inline

#This is for displaying all outputs interactively in the notebook, not just the last-one which is default in Jupyter.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

'''For reference, the options for that are 'all', 'none', 'last' and 'last_expr'. 
The difference between 'last' and 'last_expr': if your cell ends with, say, a loop containing an expression, 
'last' will show you the results from that expression in each iteration of the loop. 
'last_expr' (the default) won't show that: it will only display the result of a bare expression at the end of the cell.'''
#https://stackoverflow.com/questions/36786722/how-to-display-full-output-in-jupyter-not-only-last-result


gis = GIS()

#Get the item ids of Layers from ArcGIS Online
itemUSCounties = gis.content.get('628578697fb24d8ea4c32fa0c5ae1843')
itemCountries = gis.content.get('c0b356e20b30490c8b8b4c7bb9554e7c')

#Get the feature layers from item through indexing
deathsByUSCounty = itemUSCounties.layers[0]
deathsByCountry = itemCountries.layers[2]

#Create a country wise deaths spatial dataframe and check no of rows & columns
sdf = pd.DataFrame.spatial.from_layer(deathsByCountry)
print(f"Countrywise Deaths Feature Layer has {sdf.shape[0]} rows and {sdf.shape[1]} columns")

#Create a US County wise deaths spatial dataframe and check no.of rows & columns
sdfc = pd.DataFrame.spatial.from_layer(deathsByUSCounty)
print(f"US Counties Feature Layer has {sdfc.shape[0]} rows and {sdfc.shape[1]} columns")

#Adjust as per your requirements to display max rows/columns
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

#Get Country wise Deaths,confirmed cases grouped by country sorted by deaths
sdfd = sdf[['Country_Region','Deaths','Confirmed','Recovered','Active']]
deathcount = sdfd.sort_values(by='Deaths',ascending=False)

deathcount.reset_index(drop=True,inplace=True)

#Apply gradient style and hide index
CountryWiseDeaths = deathcount.style.format({"Country_Region": lambda x:x.upper()})\
.background_gradient(cmap="Blues").hide_index()

#Apply bar style and hide index
CountryWiseDeaths_bar = deathcount.style.format({"Country_Region": lambda x:x.upper()})\
.bar(subset=["Deaths",], color='lightgreen')\
.bar(subset=["Confirmed"], color='#ee1f5f')\
.bar(subset=["Recovered"], color='#FFA07A')\
.bar(subset=["Active"],color="#ffa600").hide_index()

def plot_pandas_style(styler):
    """Currently pandas stylers have an unforatinate indent in the html they render
    See: https://github.com/pandas-dev/pandas/issues/15651

    Example
    -------
    plot_pandas_style(df.style.set_caption('this is my caption'))
    """
    from IPython.core.display import HTML
    html = '\n'.join([line.lstrip() for line in styler.render().split('\n')])
    return HTML(html)

#Display both
CountryWiseDeaths_bar
CountryWiseDeaths

#export to excel-- CSV not supported as its plain text format
CountryWiseDeaths.to_excel('Covid-CountryWiseDeaths-data.xlsx')
# Out:
# "For reference, the options for that are 'all', 'none', 'last' and 'last_expr'. \nThe difference between 'last' and 'last_expr': if your cell ends with, say, a loop containing an expression, \n'last' will show you the results from that expression in each iteration of the loop. \n'last_expr' (the default) won't show that: it will only display the result of a bare expression at the end of the cell."
# Countrywise Deaths Feature Layer has 185 rows and 10 columns
# US Counties Feature Layer has 2653 rows and 16 columns
# <style  type="text/css" >
#     #T_00f852ca_7afa_11ea_b116_a44cc866463arow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 30.8%, transparent 30.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 36.6%, transparent 36.6%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 100.0%, transparent 100.0%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.3%, transparent 91.3%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 33.6%, transparent 33.6%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 84.5%, transparent 84.5%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 32.9%, transparent 32.9%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 67.1%, transparent 67.1%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 88.4%, transparent 88.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 66.9%, transparent 66.9%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 25.5%, transparent 25.5%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 30.1%, transparent 30.1%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 85.8%, transparent 85.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 43.7%, transparent 43.7%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 14.1%, transparent 14.1%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.5%, transparent 0.5%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 59.4%, transparent 59.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 22.5%, transparent 22.5%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 14.2%, transparent 14.2%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 41.6%, transparent 41.6%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 30.8%, transparent 30.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 18.3%, transparent 18.3%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 17.8%, transparent 17.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 100.0%, transparent 100.0%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 1.9%, transparent 1.9%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 14.3%, transparent 14.3%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 25.4%, transparent 25.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 67.4%, transparent 67.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 65.3%, transparent 65.3%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 13.8%, transparent 13.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 5.4%, transparent 5.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 6.6%, transparent 6.6%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 17.9%, transparent 17.9%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 13.2%, transparent 13.2%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 4.7%, transparent 4.7%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 0.4%, transparent 0.4%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ffa600 19.8%, transparent 19.8%);
#         }    #T_00f852ca_7afa_11ea_b116_a44cc866463arow10_col1 {
#             wi
# <style  type="text/css" >
#     #T_01160010_7afa_11ea_8a01_a44cc866463arow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow0_col2 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow0_col3 {
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow1_col1 {
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow1_col3 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow1_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow2_col1 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow2_col2 {
#             background-color:  #add0e6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow2_col3 {
#             background-color:  #3686c0;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow2_col4 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow3_col1 {
#             background-color:  #3686c0;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow3_col2 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow3_col3 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow3_col4 {
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow4_col1 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow4_col2 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow4_col3 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow4_col4 {
#             background-color:  #4d99ca;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow5_col1 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow5_col2 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow5_col3 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow5_col4 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow6_col1 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow6_col2 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow6_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow6_col4 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow7_col1 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow7_col2 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow7_col3 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow7_col4 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow8_col1 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow8_col2 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow8_col3 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow8_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow9_col1 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow9_col2 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow9_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow9_col4 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow10_col1 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow10_col2 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow10_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow10_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow11_col1 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow11_col2 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow11_col3 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow11_col4 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow12_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow12_col2 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow12_col3 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow12_col4 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow13_col1 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow13_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow13_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow13_col4 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow14_col1 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow14_col2 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow14_col3 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_01160010_7afa_11ea_8a01_a44cc866463arow14_col4 {
#             background-color:  #f7fbff;

# %%
#Renaming 'Admin2' column in US Counties dataset to 'County' in the dataset
sdfc.rename(columns={"Admin2":"County"},inplace=True)

#Extract the required columns and sort them by deaths
sdfcounty = sdfc[['Province_State','County','Confirmed','Deaths']].copy()
sdfcounty.sort_values(by=['Deaths'],ascending=[False],inplace=True)

#Creating a pivot table and summing aggregation
df_pivot = pd.pivot_table(sdfcounty,values=['Confirmed','Deaths'],index=['Province_State','County'],aggfunc=np.sum)
df_pivot.sort_values(by='Deaths',ascending=False,inplace=True)

#Eliminating counties that have both confirmed and death cases as 0
#We want counties where there are confirmed cases but not deaths hence doing 'or' condition
filt = ~(df_pivot.Deaths == 0) | ~(df_pivot.Confirmed == 0)
df_pivot_filt = df_pivot[filt]


#Get the aggregated state,county dataframe without filtering
#----Use this if for exporting if you dont want filtering---------
b = pd.concat([
    d.append(d.sum().rename((k, 'TOTAL')))
    for k, d in df_pivot.groupby(level=0)
]).append(df_pivot.sum().rename(('USA-TOTAL', '')))

#b.style.apply(lambda x: ['background-color:red' if (x.Deaths>0) else '' for i in x], axis=1)

#Get the aggregated state, county dataframe with filtering along with subtotals per state & USA-Total.
a = pd.concat([
     d.append(d.sum().rename((k, 'TOTAL')))
     for k, d in df_pivot_filt.groupby(level=0)
 ]).append(df_pivot_filt.sum().rename(('USA-TOTAL', '')))

def plot_pandas_style(styler):
    """Currently pandas stylers have an unforatinate indent in the html they render
    See: https://github.com/pandas-dev/pandas/issues/15651

    Example
    -------
    plot_pandas_style(df.style.set_caption('this is my caption'))
    """
    from IPython.core.display import HTML
    html = '\n'.join([line.lstrip() for line in styler.render().split('\n')])
    return HTML(html)


#Applying styles - Light Red for sub-totals, Light blue for deaths>0, wheat for grand-total
final_df = a.style.apply(lambda x:['background-color:#FA8072' if x.name[1]=='TOTAL' else'' for i in x],axis=1)\
.apply(lambda x:['background-color:#87CEFA' if x.Deaths>0 and x.name[1]!='TOTAL' else'' for i in x],axis=1)\
.apply(lambda x:['background-color:#F5DEB3' if x.name[0]=='USA-TOTAL' else'' for i in x],axis=1)

#Similar to what we did earlier, you can also apply bar-styles if needed

#Printing just for verification
final_df


#export to excel. --csv not supported as styling cant be applied for plain text format
final_df.to_excel('Covid-US-Countywise-data.xlsx')
# Out:
# <style  type="text/css" >
#     #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow0_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow0_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow1_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow1_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow2_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow2_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow3_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow3_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow4_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow4_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow5_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow5_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow6_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow6_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow7_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow7_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow8_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow8_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow9_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow9_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow10_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow10_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow11_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow11_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow12_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow12_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow13_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow13_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow14_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow14_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow15_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow15_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow16_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow16_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow17_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow17_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow18_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow18_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow19_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow19_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow20_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow20_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow21_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow21_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow22_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow22_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow66_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow66_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow67_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow67_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow68_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow68_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow69_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow69_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow78_col0 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow78_col1 {
#             background-color: #FA8072;
#             : ;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow79_col0 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow79_col1 {
#             : ;
#             background-color: #87CEFA;
#             : ;
#         }    #T_1a983c40_7afa_11ea_b1d8_a44cc866463arow80_col0 {
#             : ;
#             background-color: #87C
